# %% [markdown]
# # M12 Seminar: Economic and Social Problems: Insights from Big Data.
# # Term Paper.
# # Replication file №3 - time series analysis

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load US time series data
# ### Files can be found [here](https://github.com/social-connectedness-index/example-scripts)

# %%
ts_df = pd.read_csv('covid19_exploration/_intermediate/time_series_regress_dat.csv', encoding='cp1251')
ts_df['date'] = pd.to_datetime(ts_df['date'])
print(ts_df.shape)
# Out:
# (53363, 91)

# %%
# filter by date
ts_df_cases = ts_df.loc[(ts_df['date'] >= '2020-03-30') & (ts_df['date'] <= '2020-11-02')]
ts_df_deaths = ts_df.loc[(ts_df['date'] >= '2020-04-28') & (ts_df['date'] <= '2020-11-02')]

# %% [markdown]
# ### Panel A - Social proximity to cases

# %%
# specify needed variables for panel A
y_cases = ts_df_cases[['log_chg_cases_10k']]

x_cases = ts_df_cases[['log_l1_chg_swc_10k', 
                 'log_l2_chg_swc_10k', 
                 'share_within50', 
                 'share_within150', 
                 'log_l1_chg_dwc_10k', 
                 'log_l2_chg_dwc_10k', 
                 'log_l1_chg_cases_10k', 
                 'log_l2_chg_cases_10k']] 

fixed_effects_raw = ts_df_cases[['week_num', 
                           'popdensity2010_10k', 
                           'med_hhinc2016', 
                           'state_FIPS']]

# %%
# make fixed effects

# ordinal encoder for fixed effects construction
encoder = preprocessing.OrdinalEncoder()

fixed_effects_raw['time_popdensity'] = fixed_effects_raw['week_num'] * fixed_effects_raw['popdensity2010_10k']
fixed_effects_raw['time_medhhinc'] = fixed_effects_raw['week_num'] * fixed_effects_raw['med_hhinc2016']
fixed_effects_raw['time_state'] = fixed_effects_raw['week_num'] * fixed_effects_raw['state_FIPS']

time_popdensity_fe = encoder.fit_transform(fixed_effects_raw['time_popdensity'].values.reshape(-1, 1))
time_medhhinc_fe = encoder.fit_transform(fixed_effects_raw['time_medhhinc'].values.reshape(-1, 1))
time_state_fe = encoder.fit_transform(fixed_effects_raw['time_state'].values.reshape(-1, 1))
# include FEs into DataFrames
x_cases['time_popdensity_fe'] = time_popdensity_fe
x_cases['time_medhhinc_fe'] = time_medhhinc_fe
x_cases['time_state_fe'] = time_state_fe

# %%
# function which runs OLS regression for cases (any specification)
def run_regression_cases(cols_to_use):
    x = x_cases[cols_to_use]
    x['target'] = y_cases
    #x['const'] = 1
    x = x.dropna()
    y = x['target']
    x = x.drop(['target'], axis=1)
    print(x.shape, y.shape)
    print(f'mean target = {np.round(np.mean(y), 3)}')
    results = sm.OLS(y, x).fit()
    print(results.summary2())
    return results

# %%
# 8 specifications
cols_cases_1 = ['log_l1_chg_swc_10k', 'log_l2_chg_swc_10k', 'log_l1_chg_cases_10k', 'log_l2_chg_cases_10k', 
                'time_popdensity_fe', 'time_medhhinc_fe']

cols_cases_2 = ['log_l1_chg_swc_10k', 'log_l2_chg_swc_10k', 'log_l1_chg_cases_10k', 'log_l2_chg_cases_10k', 
                'time_popdensity_fe', 'time_medhhinc_fe', 'time_state_fe']

cols_cases_3 = ['share_within50', 'share_within150', 'log_l1_chg_cases_10k', 'log_l2_chg_cases_10k', 
                'time_popdensity_fe', 'time_medhhinc_fe']

cols_cases_4 = ['share_within50', 'share_within150', 'log_l1_chg_cases_10k', 'log_l2_chg_cases_10k', 
                'time_popdensity_fe', 'time_medhhinc_fe', 'time_state_fe']

cols_cases_5 = ['log_l1_chg_dwc_10k', 'log_l2_chg_dwc_10k', 'log_l1_chg_cases_10k', 'log_l2_chg_cases_10k', 
                'time_popdensity_fe', 'time_medhhinc_fe']

cols_cases_6 = ['log_l1_chg_dwc_10k', 'log_l2_chg_dwc_10k', 'log_l1_chg_cases_10k', 'log_l2_chg_cases_10k', 
                'time_popdensity_fe', 'time_medhhinc_fe', 'time_state_fe']

cols_cases_7 = ['log_l1_chg_swc_10k', 'log_l2_chg_swc_10k', 
                'share_within50', 'share_within150',
                'log_l1_chg_dwc_10k', 'log_l2_chg_dwc_10k', 
                'log_l1_chg_cases_10k', 'log_l2_chg_cases_10k', 
                'time_popdensity_fe', 'time_medhhinc_fe']

cols_cases_8 = ['log_l1_chg_swc_10k', 'log_l2_chg_swc_10k', 
                'share_within50', 'share_within150',
                'log_l1_chg_dwc_10k', 'log_l2_chg_dwc_10k', 
                'log_l1_chg_cases_10k', 'log_l2_chg_cases_10k', 
                'time_popdensity_fe', 'time_medhhinc_fe', 'time_state_fe']

# %%
# panel A specification - 1
print('specification A1')
res_a1 = run_regression_cases(cols_to_use=cols_cases_1)
print('X' * 100)
# panel A specification - 2
print('specification A2')
res_a2 = run_regression_cases(cols_to_use=cols_cases_2)
print('X' * 100)
# panel A specification - 3
print('specification A3')
res_a3 = run_regression_cases(cols_to_use=cols_cases_3)
print('X' * 100)
# panel A specification - 4
print('specification A4')
res_a4 = run_regression_cases(cols_to_use=cols_cases_4)
print('X' * 100)
# panel A specification - 5
print('specification A5')
res_a5 = run_regression_cases(cols_to_use=cols_cases_5)
print('X' * 100)
# panel A specification - 6
print('specification A6')
res_a6 = run_regression_cases(cols_to_use=cols_cases_6)
print('X' * 100)
# panel A specification - 7
print('specification A7')
res_a7 = run_regression_cases(cols_to_use=cols_cases_7)
print('X' * 100)
# panel A specification - 8
print('specification A8')
res_a8 = run_regression_cases(cols_to_use=cols_cases_8)
# Out:
# specification A1
# (47085, 6) (47085,)
# mean target = 2.178
#                          Results: Ordinary least squares
# =================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.914
# Dependent Variable:     target           AIC:                         105411.9575
# Date:                   2021-12-21 21:17 BIC:                         105464.5158
# No. Observations:       47085            Log-Likelihood:              -52700.
# Df Model:               6                F-statistic:                 8.331e+04
# Df Residuals:           47079            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.914            Scale:                       0.54923
# -----------------------------------------------------------------------------------
#                           Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# -----------------------------------------------------------------------------------
# log_l1_chg_swc_10k        0.7504     0.0120    62.6165   0.0000    0.7269    0.7739
# log_l2_chg_swc_10k       -0.2995     0.0127   -23.6353   0.0000   -0.3243   -0.2747
# log_l1_chg_cases_10k      0.3262     0.0079    41.2036   0.0000    0.3107    0.3417
# log_l2_chg_cases_10k      0.1447     0.0083    17.3778   0.0000    0.1283    0.1610
# time_popdensity_fe        0.0000     0.0000    18.4059   0.0000    0.0000    0.0000
# time_medhhinc_fe          0.0000     0.0000     6.1459   0.0000    0.0000    0.0000
# ---------------------------------------------------------------------------------
# Omnibus:                 2937.620           Durbin-Watson:              2.032
# Prob(Omnibus):           0.000              Jarque-Bera (JB):           12403.047
# Skew:                    0.149              Prob(JB):                   0.000
# Kurtosis:                5.497              Condition No.:              218353
# =================================================================================
# * The condition number is large (2e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification A2
# (47085, 7) (47085,)
# mean target = 2.178
#                          Results: Ordinary least squares
# =================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.914
# Dependent Variable:     target           AIC:                         105389.6878
# Date:                   2021-12-21 21:17 BIC:                         105451.0058
# No. Observations:       47085            Log-Likelihood:              -52688.
# Df Model:               7                F-statistic:                 7.145e+04
# Df Residuals:           47078            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.914            Scale:                       0.54895
# -----------------------------------------------------------------------------------
#                           Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# -----------------------------------------------------------------------------------
# log_l1_chg_swc_10k        0.7370     0.0123    59.9992   0.0000    0.7129    0.7611
# log_l2_chg_swc_10k       -0.3004     0.0127   -23.7096   0.0000   -0.3252   -0.2756
# log_l1_chg_cases_10k      0.3325     0.0080    41.4711   0.0000    0.3168    0.3482
# log_l2_chg_cases_10k      0.1473     0.0083    17.6626   0.0000    0.1310    0.1636
# time_popdensity_fe        0.0000     0.0000    17.7227   0.0000    0.0000    0.0000
# time_medhhinc_fe          0.0000     0.0000     4.2715   0.0000    0.0000    0.0000
# time_state_fe             0.0001     0.0000     4.9267   0.0000    0.0001    0.0001
# ---------------------------------------------------------------------------------
# Omnibus:                 2912.664           Durbin-Watson:              2.031
# Prob(Omnibus):           0.000              Jarque-Bera (JB):           12310.381
# Skew:                    0.142              Prob(JB):                   0.000
# Kurtosis:                5.489              Condition No.:              219311
# =================================================================================
# * The condition number is large (2e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification A3
# (47085, 6) (47085,)
# mean target = 2.178
#                          Results: Ordinary least squares
# =================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.910
# Dependent Variable:     target           AIC:                         107586.6174
# Date:                   2021-12-21 21:17 BIC:                         107639.1757
# No. Observations:       47085            Log-Likelihood:              -53787.
# Df Model:               6                F-statistic:                 7.919e+04
# Df Residuals:           47079            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.910            Scale:                       0.57519
# -----------------------------------------------------------------------------------
#                            Coef.    Std.Err.      t       P>|t|     [0.025   0.975]
# -----------------------------------------------------------------------------------
# share_within50             0.0340     0.0594     0.5716   0.5676   -0.0825   0.1505
# share_within150            0.6033     0.0453    13.3148   0.0000    0.5145   0.6921
# log_l1_chg_cases_10k       0.7159     0.0046   154.5935   0.0000    0.7068   0.7250
# log_l2_chg_cases_10k       0.0458     0.0046     9.8909   0.0000    0.0367   0.0548
# time_popdensity_fe         0.0000     0.0000     2.7862   0.0053    0.0000   0.0000
# time_medhhinc_fe           0.0000     0.0000    27.5124   0.0000    0.0000   0.0000
# ---------------------------------------------------------------------------------
# Omnibus:                 2920.729           Durbin-Watson:              2.014
# Prob(Omnibus):           0.000              Jarque-Bera (JB):           11165.753
# Skew:                    0.206              Prob(JB):                   0.000
# Kurtosis:                5.350              Condition No.:              853506
# =================================================================================
# * The condition number is large (9e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification A4
# (47085, 7) (47085,)
# mean target = 2.178
#                          Results: Ordinary least squares
# =================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.910
# Dependent Variable:     target           AIC:                         107588.6149
# Date:                   2021-12-21 21:17 BIC:                         107649.9329
# No. Observations:       47085            Log-Likelihood:              -53787.
# Df Model:               7                F-statistic:                 6.788e+04
# Df Residuals:           47078            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.910            Scale:                       0.57520
# -----------------------------------------------------------------------------------
#                            Coef.    Std.Err.      t       P>|t|     [0.025   0.975]
# -----------------------------------------------------------------------------------
# share_within50             0.0336     0.0599     0.5606   0.5751   -0.0838   0.1510
# share_within150            0.6040     0.0470    12.8377   0.0000    0.5118   0.6962
# log_l1_chg_cases_10k       0.7159     0.0046   154.5783   0.0000    0.7068   0.7250
# log_l2_chg_cases_10k       0.0458     0.0046     9.8906   0.0000    0.0367   0.0548
# time_popdensity_fe         0.0000     0.0000     2.7821   0.0054    0.0000   0.0000
# time_medhhinc_fe           0.0000     0.0000    24.8733   0.0000    0.0000   0.0000
# time_state_fe             -0.0000     0.0000    -0.0504   0.9598   -0.0000   0.0000
# ---------------------------------------------------------------------------------
# Omnibus:                 2920.817           Durbin-Watson:              2.014
# Prob(Omnibus):           0.000              Jarque-Bera (JB):           11165.619
# Skew:                    0.206              Prob(JB):                   0.000
# Kurtosis:                5.350              Condition No.:              868084
# =================================================================================
# * The condition number is large (9e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification A5
# (47085, 6) (47085,)
# mean target = 2.178
#                          Results: Ordinary least squares
# =================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.913
# Dependent Variable:     target           AIC:                         105750.2428
# Date:                   2021-12-21 21:17 BIC:                         105802.8010
# No. Observations:       47085            Log-Likelihood:              -52869.
# Df Model:               6                F-statistic:                 8.266e+04
# Df Residuals:           47079            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.913            Scale:                       0.55319
# -----------------------------------------------------------------------------------
#                           Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# -----------------------------------------------------------------------------------
# log_l1_chg_dwc_10k        0.3579     0.0062    58.0560   0.0000    0.3459    0.3700
# log_l2_chg_dwc_10k       -0.2444     0.0066   -36.8502   0.0000   -0.2574   -0.2314
# log_l1_chg_cases_10k      0.6675     0.0047   142.8050   0.0000    0.6584    0.6767
# log_l2_chg_cases_10k      0.0836     0.0048    17.3429   0.0000    0.0742    0.0931
# time_popdensity_fe        0.0000     0.0000     1.0438   0.2966   -0.0000    0.0000
# time_medhhinc_fe          0.0000     0.0000    17.1261   0.0000    0.0000    0.0000
# ---------------------------------------------------------------------------------
# Omnibus:                 2752.329           Durbin-Watson:              1.989
# Prob(Omnibus):           0.000              Jarque-Bera (JB):           10785.877
# Skew:                    0.155              Prob(JB):                   0.000
# Kurtosis:                5.324              Condition No.:              107491
# =================================================================================
# * The condition number is large (1e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification A6
# (47085, 7) (47085,)
# mean target = 2.178
#                          Results: Ordinary least squares
# =================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.913
# Dependent Variable:     target           AIC:                         105728.3548
# Date:                   2021-12-21 21:17 BIC:                         105789.6727
# No. Observations:       47085            Log-Likelihood:              -52857.
# Df Model:               7                F-statistic:                 7.089e+04
# Df Residuals:           47078            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.913            Scale:                       0.55292
# -----------------------------------------------------------------------------------
#                           Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# -----------------------------------------------------------------------------------
# log_l1_chg_dwc_10k        0.3663     0.0064    57.2766   0.0000    0.3537    0.3788
# log_l2_chg_dwc_10k       -0.2449     0.0066   -36.9226   0.0000   -0.2579   -0.2319
# log_l1_chg_cases_10k      0.6661     0.0047   142.2516   0.0000    0.6569    0.6753
# log_l2_chg_cases_10k      0.0823     0.0048    17.0567   0.0000    0.0729    0.0918
# time_popdensity_fe        0.0000     0.0000     0.7941   0.4271   -0.0000    0.0000
# time_medhhinc_fe          0.0000     0.0000    17.8130   0.0000    0.0000    0.0000
# time_state_fe            -0.0001     0.0000    -4.8878   0.0000   -0.0002   -0.0001
# ---------------------------------------------------------------------------------
# Omnibus:                 2753.327           Durbin-Watson:              1.989
# Prob(Omnibus):           0.000              Jarque-Bera (JB):           10746.351
# Skew:                    0.158              Prob(JB):                   0.000
# Kurtosis:                5.319              Condition No.:              108346
# =================================================================================
# * The condition number is large (1e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification A7
# (47085, 10) (47085,)
# mean target = 2.178
#                          Results: Ordinary least squares
# =================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.917
# Dependent Variable:     target           AIC:                         103898.4200
# Date:                   2021-12-21 21:17 BIC:                         103986.0171
# No. Observations:       47085            Log-Likelihood:              -51939.
# Df Model:               10               F-statistic:                 5.178e+04
# Df Residuals:           47075            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.917            Scale:                       0.53181
# -----------------------------------------------------------------------------------
#                           Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# -----------------------------------------------------------------------------------
# log_l1_chg_swc_10k        0.4804     0.0150    32.0052   0.0000    0.4510    0.5099
# log_l2_chg_swc_10k       -0.0244     0.0150    -1.6297   0.1032   -0.0539    0.0050
# share_within50            0.6283     0.0581    10.8063   0.0000    0.5143    0.7422
# share_within150          -0.7265     0.0570   -12.7468   0.0000   -0.8382   -0.6148
# log_l1_chg_dwc_10k        0.3508     0.0125    28.0759   0.0000    0.3263    0.3753
# log_l2_chg_dwc_10k       -0.3009     0.0086   -34.8952   0.0000   -0.3178   -0.2840
# log_l1_chg_cases_10k      0.4058     0.0085    47.6540   0.0000    0.3891    0.4225
# log_l2_chg_cases_10k      0.0624     0.0087     7.1681   0.0000    0.0453    0.0795
# time_popdensity_fe        0.0000     0.0000     2.7152   0.0066    0.0000    0.0000
# time_medhhinc_fe          0.0000     0.0000     6.4108   0.0000    0.0000    0.0000
# ---------------------------------------------------------------------------------
# Omnibus:                 2797.816           Durbin-Watson:              1.968
# Prob(Omnibus):           0.000              Jarque-Bera (JB):           11788.557
# Skew:                    0.111              Prob(JB):                   0.000
# Kurtosis:                5.441              Condition No.:              933795
# =================================================================================
# * The condition number is large (9e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification A8
# (47085, 11) (47085,)
# mean target = 2.178
#                          Results: Ordinary least squares
# =================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.917
# Dependent Variable:     target           AIC:                         103900.4124
# Date:                   2021-12-21 21:17 BIC:                         103996.7692
# No. Observations:       47085            Log-Likelihood:              -51939.
# Df Model:               11               F-statistic:                 4.707e+04
# Df Residuals:           47074            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.917            Scale:                       0.53182
# -----------------------------------------------------------------------------------
#                           Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# -----------------------------------------------------------------------------------
# log_l1_chg_swc_10k        0.4804     0.0150    31.9734   0.0000    0.4509    0.5098
# log_l2_chg_swc_10k       -0.0245     0.0150    -1.6312   0.1029   -0.0539    0.0049
# share_within50            0.6277     0.0585    10.7218   0.0000    0.5129    0.7424
# share_within150          -0.7259     0.0575   -12.6292   0.0000   -0.8385   -0.6132
# log_l1_chg_dwc_10k        0.3509     0.0125    27.9907   0.0000    0.3263    0.3755
# log_l2_chg_dwc_10k       -0.3008     0.0086   -34.8596   0.0000   -0.3177   -0.2839
# log_l1_chg_cases_10k      0.4058     0.0085    47.6482   0.0000    0.3891    0.4225
# log_l2_chg_cases_10k      0.0624     0.0087     7.1677   0.0000    0.0453    0.0795
# time_popdensity_fe        0.0000     0.0000     2.7132   0.0067    0.0000    0.0000
# time_medhhinc_fe          0.0000     0.0000     6.2152   0.0000    0.0000    0.0000
# time_state_fe            -0.0000     0.0000    -0.0873   0.9304   -0.0000    0.0000
# ---------------------------------------------------------------------------------
# Omnibus:                 2797.757           Durbin-Watson:              1.968
# Prob(Omnibus):           0.000              Jarque-Bera (JB):           11787.381
# Skew:                    0.112              Prob(JB):                   0.000
# Kurtosis:                5.441              Condition No.:              941471
# =================================================================================
# * The condition number is large (9e+05). This might indicate             strong
# multicollinearity or other numerical problems.

# %% [markdown]
# ### Panel B - Social proximity to deaths

# %%
# panel B specification - full
y_deaths = ts_df_deaths[['log_chg_deaths_10k_4wk']]

x_deaths = ts_df_deaths[['log_l2_chg_swd_10k_4wk', 
                 'log_l4_chg_swd_10k_4wk', 
                 'share_within50', 
                 'share_within150', 
                 'log_l2_chg_dwd_10k_4wk', 
                 'log_l4_chg_dwd_10k_4wk', 
                 'log_l2_chg_deaths_10k_4wk', 
                 'log_l4_chg_deaths_10k_4wk']] 

fixed_effects_raw = ts_df_deaths[['week_num', 
                           'popdensity2010_10k', 
                           'med_hhinc2016', 
                           'state_FIPS']]

# ordinal encoder for fixed effects construction
encoder = preprocessing.OrdinalEncoder()

fixed_effects_raw['time_popdensity'] = fixed_effects_raw['week_num'] * fixed_effects_raw['popdensity2010_10k']
fixed_effects_raw['time_medhhinc'] = fixed_effects_raw['week_num'] * fixed_effects_raw['med_hhinc2016']
fixed_effects_raw['time_state'] = fixed_effects_raw['week_num'] * fixed_effects_raw['state_FIPS']

time_popdensity_fe = encoder.fit_transform(fixed_effects_raw['time_popdensity'].values.reshape(-1, 1))
time_medhhinc_fe = encoder.fit_transform(fixed_effects_raw['time_medhhinc'].values.reshape(-1, 1))
time_state_fe = encoder.fit_transform(fixed_effects_raw['time_state'].values.reshape(-1, 1))
# add FEs to the main DataFrame
x_deaths['time_popdensity_fe'] = time_popdensity_fe
x_deaths['time_medhhinc_fe'] = time_medhhinc_fe
x_deaths['time_state_fe'] = time_state_fe

# %%
# function that fits OLS regression for deaths (any specification)
def run_regression_deaths(cols_to_use):
    x = x_deaths[cols_to_use]
    x['target'] = y_deaths
    #x['const'] = 1
    x = x.dropna()
    y = x['target']
    x = x.drop(['target'], axis=1)
    print(x.shape, y.shape)
    print(f'mean target = {np.round(np.mean(y), 3)}')
    results = sm.OLS(y, x).fit()
    print(results.summary2())
    return results

# %%
# 8 specifications for deaths
cols_deaths_1 = ['log_l2_chg_swd_10k_4wk', 'log_l4_chg_swd_10k_4wk', 
                'log_l2_chg_deaths_10k_4wk', 'log_l4_chg_deaths_10k_4wk', 
                'time_popdensity_fe', 'time_medhhinc_fe']

cols_deaths_2 = ['log_l2_chg_swd_10k_4wk', 'log_l4_chg_swd_10k_4wk', 
                'log_l2_chg_deaths_10k_4wk', 'log_l4_chg_deaths_10k_4wk', 
                'time_popdensity_fe', 'time_medhhinc_fe', 'time_state_fe']

cols_deaths_3 = ['share_within50', 'share_within150', 
                'log_l2_chg_deaths_10k_4wk', 'log_l4_chg_deaths_10k_4wk', 
                'time_popdensity_fe', 'time_medhhinc_fe']

cols_deaths_4 = ['share_within50', 'share_within150', 
                'log_l2_chg_deaths_10k_4wk', 'log_l4_chg_deaths_10k_4wk', 
                'time_popdensity_fe', 'time_medhhinc_fe', 'time_state_fe']

cols_deaths_5 = ['log_l2_chg_dwd_10k_4wk', 'log_l4_chg_dwd_10k_4wk',  
                'log_l2_chg_deaths_10k_4wk', 'log_l4_chg_deaths_10k_4wk', 
                'time_popdensity_fe', 'time_medhhinc_fe']

cols_deaths_6 = ['log_l2_chg_dwd_10k_4wk', 'log_l4_chg_dwd_10k_4wk',  
                'log_l2_chg_deaths_10k_4wk', 'log_l4_chg_deaths_10k_4wk',
                'time_popdensity_fe', 'time_medhhinc_fe', 'time_state_fe']

cols_deaths_7 = ['log_l2_chg_swd_10k_4wk', 'log_l4_chg_swd_10k_4wk', 
                'share_within50', 'share_within150',
                'log_l2_chg_dwd_10k_4wk', 'log_l4_chg_dwd_10k_4wk', 
                'log_l2_chg_deaths_10k_4wk', 'log_l4_chg_deaths_10k_4wk', 
                'time_popdensity_fe', 'time_medhhinc_fe']

cols_deaths_8 = ['log_l2_chg_swd_10k_4wk', 'log_l4_chg_swd_10k_4wk', 
                'share_within50', 'share_within150',
                'log_l2_chg_dwd_10k_4wk', 'log_l4_chg_dwd_10k_4wk', 
                'log_l2_chg_deaths_10k_4wk', 'log_l4_chg_deaths_10k_4wk',  
                'time_popdensity_fe', 'time_medhhinc_fe', 'time_state_fe']

# %%
# panel B specification - 1
print('specification B1')
res_b1 = run_regression_deaths(cols_to_use=cols_deaths_1)
print('X' * 100)
# panel B specification - 2
print('specification B2')
res_b2 = run_regression_deaths(cols_to_use=cols_deaths_2)
print('X' * 100)
# panel B specification - 3
print('specification B3')
res_b3 = run_regression_deaths(cols_to_use=cols_deaths_3)
print('X' * 100)
# panel B specification - 4
print('specification B4')
res_b4 = run_regression_deaths(cols_to_use=cols_deaths_4)
print('X' * 100)
# panel B specification - 5
print('specification B5')
res_b5 = run_regression_deaths(cols_to_use=cols_deaths_5)
print('X' * 100)
# panel B specification - 6
print('specification B6')
res_b6 = run_regression_deaths(cols_to_use=cols_deaths_6)
print('X' * 100)
# panel B specification - 7
print('specification B7')
res_b7 = run_regression_deaths(cols_to_use=cols_deaths_7)
print('X' * 100)
# panel B specification - 8
print('specification B8')
res_b8 = run_regression_deaths(cols_to_use=cols_deaths_8)
# Out:
# specification B1
# (40807, 6) (40807,)
# mean target = 0.369
#                         Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.535
# Dependent Variable:     target           AIC:                         46628.5964
# Date:                   2021-12-21 21:17 BIC:                         46680.2960
# No. Observations:       40807            Log-Likelihood:              -23308.
# Df Model:               6                F-statistic:                 7819.
# Df Residuals:           40801            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.535            Scale:                       0.18353
# ---------------------------------------------------------------------------------
#                                Coef.   Std.Err.     t     P>|t|    [0.025  0.975]
# ---------------------------------------------------------------------------------
# log_l2_chg_swd_10k_4wk         0.5636    0.0149  37.8006  0.0000   0.5344  0.5928
# log_l4_chg_swd_10k_4wk        -0.0254    0.0164  -1.5442  0.1226  -0.0576  0.0068
# log_l2_chg_deaths_10k_4wk      0.1698    0.0105  16.1808  0.0000   0.1492  0.1903
# log_l4_chg_deaths_10k_4wk     -0.0053    0.0117  -0.4569  0.6477  -0.0282  0.0175
# time_popdensity_fe             0.0000    0.0000  21.8741  0.0000   0.0000  0.0000
# time_medhhinc_fe               0.0000    0.0000   3.1287  0.0018   0.0000  0.0000
# --------------------------------------------------------------------------------
# Omnibus:                 14150.695          Durbin-Watson:             1.077
# Prob(Omnibus):           0.000              Jarque-Bera (JB):          67832.188
# Skew:                    1.625              Prob(JB):                  0.000
# Kurtosis:                8.416              Condition No.:             344533
# ================================================================================
# * The condition number is large (3e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification B2
# (40807, 7) (40807,)
# mean target = 0.369
#                         Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.536
# Dependent Variable:     target           AIC:                         46497.7569
# Date:                   2021-12-21 21:17 BIC:                         46558.0732
# No. Observations:       40807            Log-Likelihood:              -23242.
# Df Model:               7                F-statistic:                 6742.
# Df Residuals:           40800            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.536            Scale:                       0.18294
# ---------------------------------------------------------------------------------
#                               Coef.   Std.Err.     t     P>|t|    [0.025   0.975]
# ---------------------------------------------------------------------------------
# log_l2_chg_swd_10k_4wk        0.5410    0.0150  36.0319  0.0000   0.5116   0.5704
# log_l4_chg_swd_10k_4wk       -0.0255    0.0164  -1.5558  0.1198  -0.0577   0.0066
# log_l2_chg_deaths_10k_4wk     0.1812    0.0105  17.2210  0.0000   0.1606   0.2018
# log_l4_chg_deaths_10k_4wk    -0.0014    0.0117  -0.1178  0.9063  -0.0242   0.0215
# time_popdensity_fe            0.0000    0.0000  18.9220  0.0000   0.0000   0.0000
# time_medhhinc_fe             -0.0000    0.0000  -3.3887  0.0007  -0.0000  -0.0000
# time_state_fe                 0.0001    0.0000  11.5340  0.0000   0.0001   0.0002
# --------------------------------------------------------------------------------
# Omnibus:                 14018.891          Durbin-Watson:             1.078
# Prob(Omnibus):           0.000              Jarque-Bera (JB):          66071.914
# Skew:                    1.614              Prob(JB):                  0.000
# Kurtosis:                8.332              Condition No.:             345050
# ================================================================================
# * The condition number is large (3e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification B3
# (40807, 6) (40807,)
# mean target = 0.369
#                         Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.525
# Dependent Variable:     target           AIC:                         47501.4632
# Date:                   2021-12-21 21:17 BIC:                         47553.1629
# No. Observations:       40807            Log-Likelihood:              -23745.
# Df Model:               6                F-statistic:                 7509.
# Df Residuals:           40801            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.525            Scale:                       0.18750
# ---------------------------------------------------------------------------------
#                                Coef.   Std.Err.     t     P>|t|    [0.025  0.975]
# ---------------------------------------------------------------------------------
# share_within50                 0.0973    0.0363   2.6801  0.0074   0.0261  0.1684
# share_within150                0.1498    0.0275   5.4576  0.0000   0.0960  0.2037
# log_l2_chg_deaths_10k_4wk      0.5110    0.0053  97.1835  0.0000   0.5007  0.5213
# log_l4_chg_deaths_10k_4wk      0.0181    0.0057   3.1503  0.0016   0.0068  0.0293
# time_popdensity_fe             0.0000    0.0000   8.8420  0.0000   0.0000  0.0000
# time_medhhinc_fe               0.0000    0.0000   1.2654  0.2058  -0.0000  0.0000
# --------------------------------------------------------------------------------
# Omnibus:                 14431.074          Durbin-Watson:             1.075
# Prob(Omnibus):           0.000              Jarque-Bera (JB):          65618.637
# Skew:                    1.682              Prob(JB):                  0.000
# Kurtosis:                8.222              Condition No.:             671856
# ================================================================================
# * The condition number is large (7e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification B4
# (40807, 7) (40807,)
# mean target = 0.369
#                         Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.525
# Dependent Variable:     target           AIC:                         47503.1490
# Date:                   2021-12-21 21:17 BIC:                         47563.4653
# No. Observations:       40807            Log-Likelihood:              -23745.
# Df Model:               7                F-statistic:                 6436.
# Df Residuals:           40800            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.525            Scale:                       0.18750
# ---------------------------------------------------------------------------------
#                                Coef.   Std.Err.     t     P>|t|    [0.025  0.975]
# ---------------------------------------------------------------------------------
# share_within50                 0.1001    0.0366   2.7320  0.0063   0.0283  0.1720
# share_within150                0.1451    0.0287   5.0556  0.0000   0.0889  0.2014
# log_l2_chg_deaths_10k_4wk      0.5111    0.0053  97.1682  0.0000   0.5007  0.5214
# log_l4_chg_deaths_10k_4wk      0.0182    0.0057   3.1637  0.0016   0.0069  0.0294
# time_popdensity_fe             0.0000    0.0000   8.8521  0.0000   0.0000  0.0000
# time_medhhinc_fe               0.0000    0.0000   0.9400  0.3472  -0.0000  0.0000
# time_state_fe                  0.0000    0.0000   0.5605  0.5752  -0.0000  0.0000
# --------------------------------------------------------------------------------
# Omnibus:                 14424.052          Durbin-Watson:             1.075
# Prob(Omnibus):           0.000              Jarque-Bera (JB):          65547.050
# Skew:                    1.681              Prob(JB):                  0.000
# Kurtosis:                8.219              Condition No.:             685479
# ================================================================================
# * The condition number is large (7e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification B5
# (40807, 6) (40807,)
# mean target = 0.369
#                         Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.531
# Dependent Variable:     target           AIC:                         46952.1009
# Date:                   2021-12-21 21:17 BIC:                         47003.8005
# No. Observations:       40807            Log-Likelihood:              -23470.
# Df Model:               6                F-statistic:                 7703.
# Df Residuals:           40801            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.531            Scale:                       0.18499
# ---------------------------------------------------------------------------------
#                               Coef.   Std.Err.     t     P>|t|    [0.025   0.975]
# ---------------------------------------------------------------------------------
# log_l2_chg_dwd_10k_4wk        0.1656    0.0050  33.2170  0.0000   0.1558   0.1754
# log_l4_chg_dwd_10k_4wk       -0.0404    0.0053  -7.6452  0.0000  -0.0507  -0.0300
# log_l2_chg_deaths_10k_4wk     0.4752    0.0054  88.2499  0.0000   0.4646   0.4858
# log_l4_chg_deaths_10k_4wk     0.0218    0.0060   3.6266  0.0003   0.0100   0.0335
# time_popdensity_fe            0.0000    0.0000   7.5192  0.0000   0.0000   0.0000
# time_medhhinc_fe             -0.0000    0.0000  -3.1732  0.0015  -0.0000  -0.0000
# --------------------------------------------------------------------------------
# Omnibus:                 14370.348          Durbin-Watson:             1.068
# Prob(Omnibus):           0.000              Jarque-Bera (JB):          64768.491
# Skew:                    1.678              Prob(JB):                  0.000
# Kurtosis:                8.180              Condition No.:             115908
# ================================================================================
# * The condition number is large (1e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification B6
# (40807, 7) (40807,)
# mean target = 0.369
#                         Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.531
# Dependent Variable:     target           AIC:                         46952.1598
# Date:                   2021-12-21 21:17 BIC:                         47012.4760
# No. Observations:       40807            Log-Likelihood:              -23469.
# Df Model:               7                F-statistic:                 6603.
# Df Residuals:           40800            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.531            Scale:                       0.18499
# ---------------------------------------------------------------------------------
#                               Coef.   Std.Err.     t     P>|t|    [0.025   0.975]
# ---------------------------------------------------------------------------------
# log_l2_chg_dwd_10k_4wk        0.1682    0.0053  31.5432  0.0000   0.1578   0.1787
# log_l4_chg_dwd_10k_4wk       -0.0401    0.0053  -7.5871  0.0000  -0.0505  -0.0297
# log_l2_chg_deaths_10k_4wk     0.4746    0.0054  87.8300  0.0000   0.4640   0.4852
# log_l4_chg_deaths_10k_4wk     0.0212    0.0060   3.5224  0.0004   0.0094   0.0330
# time_popdensity_fe            0.0000    0.0000   7.4587  0.0000   0.0000   0.0000
# time_medhhinc_fe             -0.0000    0.0000  -2.4846  0.0130  -0.0000  -0.0000
# time_state_fe                -0.0000    0.0000  -1.3931  0.1636  -0.0000   0.0000
# --------------------------------------------------------------------------------
# Omnibus:                 14385.563          Durbin-Watson:             1.068
# Prob(Omnibus):           0.000              Jarque-Bera (JB):          64947.971
# Skew:                    1.679              Prob(JB):                  0.000
# Kurtosis:                8.189              Condition No.:             116434
# ================================================================================
# * The condition number is large (1e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification B7
# (40807, 10) (40807,)
# mean target = 0.369
#                         Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.541
# Dependent Variable:     target           AIC:                         46125.1850
# Date:                   2021-12-21 21:17 BIC:                         46211.3511
# No. Observations:       40807            Log-Likelihood:              -23053.
# Df Model:               10               F-statistic:                 4801.
# Df Residuals:           40797            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.541            Scale:                       0.18126
# ---------------------------------------------------------------------------------
#                               Coef.   Std.Err.     t     P>|t|    [0.025   0.975]
# ---------------------------------------------------------------------------------
# log_l2_chg_swd_10k_4wk        0.4245    0.0175  24.1932  0.0000   0.3901   0.4589
# log_l4_chg_swd_10k_4wk        0.0405    0.0189   2.1432  0.0321   0.0035   0.0775
# share_within50                0.1333    0.0360   3.7037  0.0002   0.0627   0.2038
# share_within150              -0.0041    0.0286  -0.1437  0.8857  -0.0602   0.0519
# log_l2_chg_dwd_10k_4wk        0.0646    0.0088   7.3736  0.0000   0.0474   0.0818
# log_l4_chg_dwd_10k_4wk       -0.0483    0.0061  -7.9531  0.0000  -0.0603  -0.0364
# log_l2_chg_deaths_10k_4wk     0.2284    0.0111  20.5353  0.0000   0.2066   0.2502
# log_l4_chg_deaths_10k_4wk    -0.0224    0.0122  -1.8336  0.0667  -0.0463   0.0015
# time_popdensity_fe            0.0000    0.0000   5.4052  0.0000   0.0000   0.0000
# time_medhhinc_fe             -0.0000    0.0000  -0.8779  0.3800  -0.0000   0.0000
# --------------------------------------------------------------------------------
# Omnibus:                 14083.605          Durbin-Watson:             1.071
# Prob(Omnibus):           0.000              Jarque-Bera (JB):          65424.982
# Skew:                    1.628              Prob(JB):                  0.000
# Kurtosis:                8.280              Condition No.:             677062
# ================================================================================
# * The condition number is large (7e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# specification B8
# (40807, 11) (40807,)
# mean target = 0.369
#                         Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.541
# Dependent Variable:     target           AIC:                         46125.0114
# Date:                   2021-12-21 21:17 BIC:                         46219.7941
# No. Observations:       40807            Log-Likelihood:              -23052.
# Df Model:               11               F-statistic:                 4365.
# Df Residuals:           40796            Prob (F-statistic):          0.00
# R-squared (uncentered): 0.541            Scale:                       0.18126
# ---------------------------------------------------------------------------------
#                               Coef.   Std.Err.     t     P>|t|    [0.025   0.975]
# ---------------------------------------------------------------------------------
# log_l2_chg_swd_10k_4wk        0.4252    0.0176  24.2250  0.0000   0.3908   0.4596
# log_l4_chg_swd_10k_4wk        0.0423    0.0189   2.2323  0.0256   0.0052   0.0793
# share_within50                0.1417    0.0364   3.8901  0.0001   0.0703   0.2131
# share_within150              -0.0156    0.0297  -0.5277  0.5977  -0.0738   0.0425
# log_l2_chg_dwd_10k_4wk        0.0641    0.0088   7.3126  0.0000   0.0469   0.0813
# log_l4_chg_dwd_10k_4wk       -0.0493    0.0061  -8.0657  0.0000  -0.0613  -0.0373
# log_l2_chg_deaths_10k_4wk     0.2282    0.0111  20.5157  0.0000   0.2064   0.2500
# log_l4_chg_deaths_10k_4wk    -0.0229    0.0122  -1.8777  0.0604  -0.0469   0.0010
# time_popdensity_fe            0.0000    0.0000   5.4278  0.0000   0.0000   0.0000
# time_medhhinc_fe             -0.0000    0.0000  -1.2917  0.1965  -0.0000   0.0000
# time_state_fe                 0.0000    0.0000   1.4742  0.1404  -0.0000   0.0001
# --------------------------------------------------------------------------------
# Omnibus:                 14066.008          Durbin-Watson:             1.071
# Prob(Omnibus):           0.000              Jarque-Bera (JB):          65258.720
# Skew:                    1.626              Prob(JB):                  0.000
# Kurtosis:                8.272              Condition No.:             691814
# ================================================================================
# * The condition number is large (7e+05). This might indicate             strong
# multicollinearity or other numerical problems.

# %% [markdown]
# ### Now we need to construct 2 panels from 18 resulting OLS tables

# %%
# function that parces p-values in numeric format and returns p-values in ***/**/* format
def get_params_stars(ols_results):
    p_value_sign = []
    for i in ols_results.pvalues.values:
        if i < 0.01:
            p_value_sign.append('***')
        elif i < 0.05:
            p_value_sign.append('**')
        elif i < 0.1:
            p_value_sign.append('*')
        else:
            p_value_sign.append(' ')
    params_stars = []
    for i in range(ols_results.params.shape[0]):
        params_stars.append(str(ols_results.params.round(3).iloc[i]) + p_value_sign[i])
    output_df = pd.DataFrame()
    output_df.index = ols_results.params.index
    output_df['coef'] = params_stars
    return output_df

# %%
# replicate panel A
cases_res = pd.DataFrame()
cases_res.index = ['log_l1_chg_swc_10k', 'log_l2_chg_swc_10k', 
                   'share_within50', 'share_within150',
                   'log_l1_chg_dwc_10k', 'log_l2_chg_dwc_10k', 
                   'log_l1_chg_cases_10k', 'log_l2_chg_cases_10k', 
                   'time_popdensity_fe', 'time_medhhinc_fe', 'time_state_fe']

for res in [res_a1, res_a2, res_a3, res_a4, res_a5, res_a6, res_a7, res_a8]:
    res_df = get_params_stars(res)
    cases_res = pd.merge(left=cases_res, right=res_df, how='left', left_index=True, right_index=True)
cases_res.columns = [f'({i})' for i in range(1, 9)]
cases_res = cases_res.fillna('-')

# %%
# print(cases_res.to_latex())

# %%
# replicate panel B
deaths_res = pd.DataFrame()
deaths_res.index = ['log_l2_chg_swd_10k_4wk', 'log_l4_chg_swd_10k_4wk', 
                    'share_within50', 'share_within150',
                    'log_l2_chg_dwd_10k_4wk', 'log_l4_chg_dwd_10k_4wk', 
                    'log_l2_chg_deaths_10k_4wk', 'log_l4_chg_deaths_10k_4wk',  
                    'time_popdensity_fe', 'time_medhhinc_fe', 'time_state_fe']

for res in [res_b1, res_b2, res_b3, res_b4, res_b5, res_b6, res_b7, res_b8]:
    res_df = get_params_stars(res)
    deaths_res = pd.merge(left=deaths_res, right=res_df, how='left', left_index=True, right_index=True)
deaths_res.columns = [f'({i})' for i in range(1, 9)]
deaths_res = deaths_res.fillna('-')

# %%
# print(deaths_res.to_latex())
